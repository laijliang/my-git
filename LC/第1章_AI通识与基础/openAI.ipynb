# %% [markdown]
# ### 1.API环境变量配置

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

# 加载环境变量
load_dotenv()

client = OpenAI(
    api_key=os.getenv("DEEPSEEK_API_KEY"),
    base_url="https://api.deepseek.com"
)

# %% [markdown]
# ### 2.调用大模型

# %%
print("🚀 正在调用大模型...")
response = client.chat.completions.create(
    model="deepseek-chat",
    messages=[
        {"role": "system", "content": "你是一名友好的AI助教。"},
        {"role": "user", "content": "你好，你是谁?"}
    ],
    stream=False
)
# Out:
# 🚀 正在调用大模型...

# %% [markdown]
# ### 3.大模型回复

# %%
print("🤖 大模型回复:", response.choices[0].message.content)
# Out:
# 🤖 大模型回复: 你好呀！我是你的智能学习助手，专注于帮助你解答问题、获取知识和完成学习任务。无论你想了解某个概念、解决一道难题，还是需要学习方法的建议，都可以随时找我聊！😊 有什么可以帮你的吗？
